# %% [markdown]
# # DATA PREPROCESSING/DATA PREPARATION
#
# 1. Data Cleaning - drop, fillna with mean, median, mode Imputation, changing dtype
# 2. Data Transformation
#     * If data is CONTINUOUS = Standard Scaler, MinMaxScaler, Robust Scaler
#     * If data is DISCRETE   = Label Encoder, One hot Encoder

# %% [markdown]
# ## 1. Import Necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ## 2. Import data

# %%
weather_data_2010 = pd.read_csv('data_clean.csv')
weather_data_2010.head(50)
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0            1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1            2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2            3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3            4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4            5    NaN      NaN  14.3     56     5    5  2010    56       S
# 5            6   28.0      NaN  14.9     66     5    6  2010    66       C
# 6            7   23.0    299.0   8.6     65     5    7  2010    65      PS
# 7            8   19.0     99.0  13.8     59     5    8  2010    59       C
# 8            9    8.0     19.0  20.1     61     5    9  2010    61      PS
# 9           10    NaN    194.0   8.6     69     5   10  2010    69       S
# 10          11    7.0      NaN   6.9      C     5   11  2010    74       C
# 11          12   16.0    256.0   9.7     69     5   12  2010    69      PS
# 12          13   11.0    290.0   9.2     66     5   13  2010    66       S
# 13          14   14.0    274.0  10.9     68     5   14  2010    68       S
# 14          15   18.0     65.0  13.2     58     5   15  2010    58       C
# 15          16   14.0    334.0  11.5     64     5   16  2010    64       S
# 16          17   34.0    307.0  12.0     66     5   17  2010    66       S
# 17          18    6.0     78.0  18.4     57     5   18  2010    57       C
# 18          19   30.0    322.0  11.5     68     5   19  2010    68      PS
# 19          20   11.0     44.0   9.7     62     5   20  2010    62       S
# 20          21    1.0      8.0   9.7     59     5   21  2010    59       S
# 21          22   11.0    320.0  16.6     73     5   22  2010    73       C
# 22          23    4.0     25.0   9.7     61     5   23  2010    61      PS
# 23          24   32.0     92.0  12.0     61   May   24  2010    61       C
# 24          25    NaN     66.0  16.6     57     5   25  2010    57      PS
# 25          26    NaN    266.0  14.9     58     5   26  2010    58       C
# 26          27    NaN      NaN   8.0     57     5   27  2010    57      PS
# 27          28   23.0     13.0  12.0     67     5   28  2010    67       S
# 28          29   45.0    252.0  14.9     81     5   29  2010    81       S
# 29          30  115.0    223.0   5.7     79     5   30  2010    79       C
# 30          31   37.0    279.0   7.4     76     5   31  2010    76      PS
# 31          32    NaN    286.0   8.6     78     6    1  2010    78       S
# 32          33    NaN    287.0   9.7     74     6    2  2010    74       C
# 33          34    NaN    242.0  16.1     67     6    3  2010    67      PS
# 34          35    NaN    186.0   9.2     84     6    4  2010    84       C
# 35          36    NaN    220.0   8.6     85     6    5  2010    85      PS
# 36          37    NaN    264.0  14.3     79     6    6  2010    79       C
# 37          38   29.0    127.0   9.7     82     6    7  2010    82      PS
# 38          39    NaN    273.0   6.9     87     6    8  2010    87       S
# 39          40   71.0    291.0  13.8     90     6    9  2010    90       S
# 40          41   39.0    323.0  11.5     87     6   10  2010    87       S
# 41          42    NaN    259.0  10.9     93     6   11  2010    93       C
# 42          43    NaN    250.0   9.2     92     6   12  2010    92      PS
# 43          44   23.0    148.0   8.0     82     6   13  2010    82       S
# 44          45    NaN    332.0  13.8     80     6   14  2010    80       S
# 45          46    NaN    322.0  11.5     79     6   15  2010    79       C
# 46          47   21.0    191.0  14.9     77     6   16  2010    77      PS
# 47          48   37.0    284.0  20.7     72     6   17  2010    72       C
# 48          49   20.0     37.0   9.2     65     6   18  2010    65      PS
# 49          50   12.0    120.0  11.5     73     6   19  2010    73       S

# %% [markdown]
# ### 3. Data Understanding

# %%
weather_data_2010.shape
# Out:
# (158, 10)

# %%
weather_data_2010.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
38/158
# Out:
# 0.24050632911392406

# %%
weather_data_2010.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
weather_data_2010.describe(include='all')
# Out:
#         Unnamed: 0       Ozone     Solar.R        Wind Temp C Month  \
# count   158.000000  120.000000  151.000000  158.000000    158   158
# unique         NaN         NaN         NaN         NaN     41     6
# top            NaN         NaN         NaN         NaN     81     9
# freq           NaN         NaN         NaN         NaN     11    34
# mean     79.500000   41.583333  185.403974    9.957595    NaN   NaN
# std      45.754781   32.620709   88.723103    3.511261    NaN   NaN
# min       1.000000    1.000000    7.000000    1.700000    NaN   NaN
# 25%      40.250000   18.000000  119.000000    7.400000    NaN   NaN
# 50%      79.500000   30.500000  197.000000    9.700000    NaN   NaN
# 75%     118.750000   61.500000  257.000000   11.875000    NaN   NaN
# max     158.000000  168.000000  334.000000   20.700000    NaN   NaN
#
#                Day    Year        Temp Weather
# count   158.000000   158.0  158.000000     155
# unique         NaN     NaN         NaN       3
# top            NaN     NaN         NaN       S
# freq           NaN     NaN         NaN      59
# mean     16.006329  2010.0   77.727848     NaN
# std       8.997166     0.0    9.377877     NaN
# min       1.000000  2010.0   56.000000     NaN
# 25%       8.000000  2010.0   72.000000     NaN
# 50%      16.000000  2010.0   78.500000     NaN
# 75%      24.000000  2010.0   84.000000     NaN
# max      31.000000  2010.0   97.000000     NaN

# %%
weather_data_2010['Weather'].unique()
# Out:
# array(['S', 'C', 'PS', nan], dtype=object)

# %% [markdown]
# ## 4. Data Preparation
#
# ### STAGE 1: Data Cleaning

# %% [markdown]
# ### 1. 1 Null value Treatment

# %%
del weather_data_2010['Unnamed: 0']

# %%
weather_data_2010.head()
# Out:
#    Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4     67     5    1  2010    67       S
# 1   36.0    118.0   8.0     72     5    2  2010    72       C
# 2   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3   18.0    313.0  11.5     62     5    4  2010    62       S
# 4    NaN      NaN  14.3     56     5    5  2010    56       S

# %% [markdown]
# ### Client, Arthi Selvaraj, agreed to drop Ozone feature because of more null values.

# %%
del weather_data_2010['Ozone']

# %%
weather_data_2010.isna().sum()
# Out:
# Solar.R    7
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %% [markdown]
# ### Client, Arthi Selvaraj, agreed to go with Mean Imputation for Solar.R feature.

# %%
weather_data_2010['Solar.R'].mean()
# Out:
# 185.40397350993376

# %%
weather_data_2010.head()
# Out:
#    Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    190.0   7.4     67     5    1  2010    67       S
# 1    118.0   8.0     72     5    2  2010    72       C
# 2    149.0  12.6     74     5    3  2010    74      PS
# 3    313.0  11.5     62     5    4  2010    62       S
# 4      NaN  14.3     56     5    5  2010    56       S

# %%
weather_data_2010['Solar.R'].fillna(value=185.4,inplace=True)

# %%
weather_data_2010.isna().sum()
# Out:
# Solar.R    0
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %% [markdown]
# ### Client, Aarthi agreed to drop that 3 observations for which Weather has been not captured properly.

# %%
weather_data_2010.dropna(axis=0,inplace=True)

# %%
weather_data_2010.isna().sum()
# Out:
# Solar.R    0
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %% [markdown]
# ### 1.2 Conversion of Datatypes

# %%
weather_data_2010.dtypes
# Out:
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_data_2010.head(10)
# Out:
#    Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    190.0   7.4     67     5    1  2010    67       S
# 1    118.0   8.0     72     5    2  2010    72       C
# 2    149.0  12.6     74     5    3  2010    74      PS
# 3    313.0  11.5     62     5    4  2010    62       S
# 4    185.4  14.3     56     5    5  2010    56       S
# 5    185.4  14.9     66     5    6  2010    66       C
# 6    299.0   8.6     65     5    7  2010    65      PS
# 7     99.0  13.8     59     5    8  2010    59       C
# 8     19.0  20.1     61     5    9  2010    61      PS
# 9    194.0   8.6     69     5   10  2010    69       S

# %%
del weather_data_2010['Temp C']

# %%
weather_data_2010.dtypes
# Out:
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_data_2010.head(40)
# Out:
#     Solar.R  Wind Month  Day  Year  Temp Weather
# 0     190.0   7.4     5    1  2010    67       S
# 1     118.0   8.0     5    2  2010    72       C
# 2     149.0  12.6     5    3  2010    74      PS
# 3     313.0  11.5     5    4  2010    62       S
# 4     185.4  14.3     5    5  2010    56       S
# 5     185.4  14.9     5    6  2010    66       C
# 6     299.0   8.6     5    7  2010    65      PS
# 7      99.0  13.8     5    8  2010    59       C
# 8      19.0  20.1     5    9  2010    61      PS
# 9     194.0   8.6     5   10  2010    69       S
# 10    185.4   6.9     5   11  2010    74       C
# 11    256.0   9.7     5   12  2010    69      PS
# 12    290.0   9.2     5   13  2010    66       S
# 13    274.0  10.9     5   14  2010    68       S
# 14     65.0  13.2     5   15  2010    58       C
# 15    334.0  11.5     5   16  2010    64       S
# 16    307.0  12.0     5   17  2010    66       S
# 17     78.0  18.4     5   18  2010    57       C
# 18    322.0  11.5     5   19  2010    68      PS
# 19     44.0   9.7     5   20  2010    62       S
# 20      8.0   9.7     5   21  2010    59       S
# 21    320.0  16.6     5   22  2010    73       C
# 22     25.0   9.7     5   23  2010    61      PS
# 23     92.0  12.0   May   24  2010    61       C
# 24     66.0  16.6     5   25  2010    57      PS
# 25    266.0  14.9     5   26  2010    58       C
# 26    185.4   8.0     5   27  2010    57      PS
# 27     13.0  12.0     5   28  2010    67       S
# 28    252.0  14.9     5   29  2010    81       S
# 29    223.0   5.7     5   30  2010    79       C
# 30    279.0   7.4     5   31  2010    76      PS
# 31    286.0   8.6     6    1  2010    78       S
# 32    287.0   9.7     6    2  2010    74       C
# 33    242.0  16.1     6    3  2010    67      PS
# 34    186.0   9.2     6    4  2010    84       C
# 35    220.0   8.6     6    5  2010    85      PS
# 36    264.0  14.3     6    6  2010    79       C
# 37    127.0   9.7     6    7  2010    82      PS
# 38    273.0   6.9     6    8  2010    87       S
# 39    291.0  13.8     6    9  2010    90       S

# %%
weather_data_2010['Month'] = pd.to_numeric(arg = weather_data_2010['Month'],errors='coerce')

# %%
weather_data_2010.head(30)
# Out:
#     Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     190.0   7.4    5.0    1  2010    67       S
# 1     118.0   8.0    5.0    2  2010    72       C
# 2     149.0  12.6    5.0    3  2010    74      PS
# 3     313.0  11.5    5.0    4  2010    62       S
# 4     185.4  14.3    5.0    5  2010    56       S
# 5     185.4  14.9    5.0    6  2010    66       C
# 6     299.0   8.6    5.0    7  2010    65      PS
# 7      99.0  13.8    5.0    8  2010    59       C
# 8      19.0  20.1    5.0    9  2010    61      PS
# 9     194.0   8.6    5.0   10  2010    69       S
# 10    185.4   6.9    5.0   11  2010    74       C
# 11    256.0   9.7    5.0   12  2010    69      PS
# 12    290.0   9.2    5.0   13  2010    66       S
# 13    274.0  10.9    5.0   14  2010    68       S
# 14     65.0  13.2    5.0   15  2010    58       C
# 15    334.0  11.5    5.0   16  2010    64       S
# 16    307.0  12.0    5.0   17  2010    66       S
# 17     78.0  18.4    5.0   18  2010    57       C
# 18    322.0  11.5    5.0   19  2010    68      PS
# 19     44.0   9.7    5.0   20  2010    62       S
# 20      8.0   9.7    5.0   21  2010    59       S
# 21    320.0  16.6    5.0   22  2010    73       C
# 22     25.0   9.7    5.0   23  2010    61      PS
# 23     92.0  12.0    NaN   24  2010    61       C
# 24     66.0  16.6    5.0   25  2010    57      PS
# 25    266.0  14.9    5.0   26  2010    58       C
# 26    185.4   8.0    5.0   27  2010    57      PS
# 27     13.0  12.0    5.0   28  2010    67       S
# 28    252.0  14.9    5.0   29  2010    81       S
# 29    223.0   5.7    5.0   30  2010    79       C

# %%
weather_data_2010.dtypes
# Out:
# Solar.R    float64
# Wind       float64
# Month      float64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_data_2010['Month'].fillna(value=5,inplace=True)

# %%
weather_data_2010.head(30)
# Out:
#     Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     190.0   7.4    5.0    1  2010    67       S
# 1     118.0   8.0    5.0    2  2010    72       C
# 2     149.0  12.6    5.0    3  2010    74      PS
# 3     313.0  11.5    5.0    4  2010    62       S
# 4     185.4  14.3    5.0    5  2010    56       S
# 5     185.4  14.9    5.0    6  2010    66       C
# 6     299.0   8.6    5.0    7  2010    65      PS
# 7      99.0  13.8    5.0    8  2010    59       C
# 8      19.0  20.1    5.0    9  2010    61      PS
# 9     194.0   8.6    5.0   10  2010    69       S
# 10    185.4   6.9    5.0   11  2010    74       C
# 11    256.0   9.7    5.0   12  2010    69      PS
# 12    290.0   9.2    5.0   13  2010    66       S
# 13    274.0  10.9    5.0   14  2010    68       S
# 14     65.0  13.2    5.0   15  2010    58       C
# 15    334.0  11.5    5.0   16  2010    64       S
# 16    307.0  12.0    5.0   17  2010    66       S
# 17     78.0  18.4    5.0   18  2010    57       C
# 18    322.0  11.5    5.0   19  2010    68      PS
# 19     44.0   9.7    5.0   20  2010    62       S
# 20      8.0   9.7    5.0   21  2010    59       S
# 21    320.0  16.6    5.0   22  2010    73       C
# 22     25.0   9.7    5.0   23  2010    61      PS
# 23     92.0  12.0    5.0   24  2010    61       C
# 24     66.0  16.6    5.0   25  2010    57      PS
# 25    266.0  14.9    5.0   26  2010    58       C
# 26    185.4   8.0    5.0   27  2010    57      PS
# 27     13.0  12.0    5.0   28  2010    67       S
# 28    252.0  14.9    5.0   29  2010    81       S
# 29    223.0   5.7    5.0   30  2010    79       C

# %%
weather_data_2010['Month'] = weather_data_2010['Month'].astype('int')

# %%
weather_data_2010.dtypes
# Out:
# Solar.R    float64
# Wind       float64
# Month        int32
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_data_2010.isna().sum()
# Out:
# Solar.R    0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
weather_data_2010.head()
# Out:
#    Solar.R  Wind  Month  Day  Year  Temp Weather
# 0    190.0   7.4      5    1  2010    67       S
# 1    118.0   8.0      5    2  2010    72       C
# 2    149.0  12.6      5    3  2010    74      PS
# 3    313.0  11.5      5    4  2010    62       S
# 4    185.4  14.3      5    5  2010    56       S

# %% [markdown]
# ## STAGE 2 : DATA TRANSFORMATION
#
# * If data is **CONTINUOUS** = Standard Scaler, MinMaxScaler, Robust Scaler
# * If data is **DISCRETE**   = Label Encoder, One hot Encoder

# %% [markdown]
# ### 1. Label Encoder

# %%
weather_data_2 = weather_data_2010.copy()
weather_data_2
# Out:
#      Solar.R  Wind  Month  Day  Year  Temp Weather
# 0      190.0   7.4      5    1  2010    67       S
# 1      118.0   8.0      5    2  2010    72       C
# 2      149.0  12.6      5    3  2010    74      PS
# 3      313.0  11.5      5    4  2010    62       S
# 4      185.4  14.3      5    5  2010    56       S
# ..       ...   ...    ...  ...   ...   ...     ...
# 153    190.0   7.4      5    1  2010    67       C
# 154    193.0   6.9      9   26  2010    70      PS
# 155    145.0  13.2      9   27  2010    77       S
# 156    191.0  14.3      9   28  2010    75       S
# 157    131.0   8.0      9   29  2010    76       C
#
# [155 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
weather_data_2['Weather'] = le.fit_transform(weather_data_2['Weather'])
weather_data_2
# Out:
#      Solar.R  Wind  Month  Day  Year  Temp  Weather
# 0      190.0   7.4      5    1  2010    67        2
# 1      118.0   8.0      5    2  2010    72        0
# 2      149.0  12.6      5    3  2010    74        1
# 3      313.0  11.5      5    4  2010    62        2
# 4      185.4  14.3      5    5  2010    56        2
# ..       ...   ...    ...  ...   ...   ...      ...
# 153    190.0   7.4      5    1  2010    67        0
# 154    193.0   6.9      9   26  2010    70        1
# 155    145.0  13.2      9   27  2010    77        2
# 156    191.0  14.3      9   28  2010    75        2
# 157    131.0   8.0      9   29  2010    76        0
#
# [155 rows x 7 columns]

# %%
weather_data_2.dtypes
# Out:
# Solar.R    float64
# Wind       float64
# Month        int32
# Day          int64
# Year         int64
# Temp         int64
# Weather      int32
# dtype: object

# %% [markdown]
# ### 2. One Hot Encoder
#
# This can be achieved by using any of the following 2 libraries:
#
# 1. Pandas - pd.get_dummies()
# 2. sklearn - OneHotEncoder()

# %%
weather_data_3 = weather_data_2010.copy()
weather_data_3.head()
# Out:
#    Solar.R  Wind  Month  Day  Year  Temp Weather
# 0    190.0   7.4      5    1  2010    67       S
# 1    118.0   8.0      5    2  2010    72       C
# 2    149.0  12.6      5    3  2010    74      PS
# 3    313.0  11.5      5    4  2010    62       S
# 4    185.4  14.3      5    5  2010    56       S

# %%
weather_data_3 = pd.get_dummies(data = weather_data_3,columns=['Weather'],drop_first=True)
weather_data_3
# Out:
#      Solar.R  Wind  Month  Day  Year  Temp  Weather_PS  Weather_S
# 0      190.0   7.4      5    1  2010    67           0          1
# 1      118.0   8.0      5    2  2010    72           0          0
# 2      149.0  12.6      5    3  2010    74           1          0
# 3      313.0  11.5      5    4  2010    62           0          1
# 4      185.4  14.3      5    5  2010    56           0          1
# ..       ...   ...    ...  ...   ...   ...         ...        ...
# 153    190.0   7.4      5    1  2010    67           0          0
# 154    193.0   6.9      9   26  2010    70           1          0
# 155    145.0  13.2      9   27  2010    77           0          1
# 156    191.0  14.3      9   28  2010    75           0          1
# 157    131.0   8.0      9   29  2010    76           0          0
#
# [155 rows x 8 columns]

# %%
weather_data_3.dtypes
# Out:
# Solar.R       float64
# Wind          float64
# Month           int32
# Day             int64
# Year            int64
# Temp            int64
# Weather_C       uint8
# Weather_PS      uint8
# Weather_S       uint8
# dtype: object

# %% [markdown]
# ### 2. OneHot Encoder

# %%
weather_data_4 = weather_data_2010.copy()
weather_data_4
# Out:
#      Solar.R  Wind  Month  Day  Year  Temp Weather
# 0      190.0   7.4      5    1  2010    67       S
# 1      118.0   8.0      5    2  2010    72       C
# 2      149.0  12.6      5    3  2010    74      PS
# 3      313.0  11.5      5    4  2010    62       S
# 4      185.4  14.3      5    5  2010    56       S
# ..       ...   ...    ...  ...   ...   ...     ...
# 153    190.0   7.4      5    1  2010    67       C
# 154    193.0   6.9      9   26  2010    70      PS
# 155    145.0  13.2      9   27  2010    77       S
# 156    191.0  14.3      9   28  2010    75       S
# 157    131.0   8.0      9   29  2010    76       C
#
# [155 rows x 7 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
ohe.fit_transform(weather_data_4['Weather'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-1b0ed792abba> in <module>
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 ohe = OneHotEncoder()
# ----> 3 ohe.fit_transform(weather_data_4['Weather'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     441         """
#     442         self._validate_keywords()
# --> 443         return super().fit_transform(X, y)
#     444
#     445     def transform(self, X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     415         """
#     416         self._validate_keywords()
# --> 417         self._fit(X, handle_unknown=self.handle_unknown,
#     418                   force_all_finite='allow-nan')
#     419         self.drop_idx_ = self._compute_drop_idx()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in _fit(self, X, handle_unknown, force_all_finite)
#      75
#      76     def _fit(self, X, handle_unknown='error', force_all_finite=True):
# ---> 77         X_list, n_samples, n_features = self._check_X(
#      78             X, force_all_finite=force_all_finite)
#      79
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in _check_X(self, X, force_all_finite)
#      42         if not (hasattr(X, 'iloc') and getattr(X, 'ndim', 0) == 2):
#      43             # if not a dataframe, do normal check_array validation
# ---> 44             X_temp = check_array(X, dtype=None,
#      45                                  force_all_finite=force_all_finite)
#      46             if (not hasattr(X, 'dtype')
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     635             # If input is 1D raise error
#     636             if array.ndim == 1:
# --> 637                 raise ValueError(
#     638                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     639                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=['S' 'C' 'PS' 'S' 'S' 'C' 'PS' 'C' 'PS' 'S' 'C' 'PS' 'S' 'S' 'C' 'S' 'S'
#  'C' 'PS' 'S' 'S' 'C' 'PS' 'C' 'PS' 'C' 'PS' 'S' 'S' 'C' 'PS' 'S' 'C' 'PS'
#  'C' 'PS' 'C' 'PS' 'S' 'S' 'S' 'C' 'PS' 'S' 'S' 'C' 'PS' 'C' 'PS' 'S' 'S'
#  'S' 'C' 'PS' 'S' 'C' 'PS' 'C' 'PS' 'S' 'S' 'S' 'C' 'PS' 'S' 'S' 'C' 'C'
#  'PS' 'C' 'PS' 'S' 'S' 'S' 'C' 'PS' 'S' 'S' 'C' 'PS' 'C' 'S' 'S' 'C' 'PS'
#  'PS' 'C' 'S' 'C' 'PS' 'C' 'PS' 'PS' 'S' 'C' 'C' 'PS' 'C' 'PS' 'S' 'S' 'S'
#  'C' 'C' 'C' 'PS' 'C' 'PS' 'S' 'S' 'C' 'PS' 'C' 'PS' 'S' 'S' 'S' 'S' 'S'
#  'C' 'C' 'PS' 'C' 'PS' 'S' 'S' 'S' 'C' 'PS' 'C' 'PS' 'S' 'S' 'PS' 'PS' 'S'
#  'PS' 'S' 'C' 'PS' 'PS' 'S' 'S' 'C' 'PS' 'C' 'PS' 'S' 'PS' 'S' 'C' 'PS'
#  'S' 'S' 'C'].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# ## ========================================================================

# %% [markdown]
# # How to choose between Label Encoder or One Hot Encoder?

# %% [markdown]
# ### Input feature:
# Based on whether it is **Parametric or a Non Parametric Model**, we will choosing between LE or OHE.
# * For **Parametric Models** - better to go with **OHE.**
# * For **Non-Parametric Models** - always go with **Label Encoding.**
#
# ### Output feature:
# Always the output feature, it must be **Label Encoder.**

# %% [markdown]
# ## ========================================================================
